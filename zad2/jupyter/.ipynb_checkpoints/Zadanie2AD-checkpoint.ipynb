# %% [markdown]
# ## Import section

# %%
# !pip install tabulate > /dev/null

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import SimpleImputer
from tabulate import tabulate

# %% [markdown]
# # Data preparation and toolbox

# %%
# toolbox
def set_percentage_of_values_to_nan(df, percentage):
    return df.mask(np.random.random(df.shape) < percentage)
def show_nan_percentage(df):
    print(df.isnull().sum() * 100 / len(df))
def hist_of_selected_column(df, column_name):
    hs = df[column_name]
    plt.hist(hs)
    plt.xlabel(column_name)
    plt.show()
def plot_of_two_columns(df, f_c, s_c):
    plt.plot(f_c,s_c, 'b.', data=df)
    plt.xlabel(f_c)
    plt.ylabel(s_c)
    plt.show()

# %%
df = pd.read_csv("./data/Olympic-atheletes.csv", sep=";")
df = df.drop(columns = 'ID')
df = df.drop_duplicates(subset="Name")

df['Height'] = set_percentage_of_values_to_nan(df['Height'], 0.05)
df['Weight'] = set_percentage_of_values_to_nan(df['Weight'], 0.05)
man_df = df[df['Sex'] == 'M']
woman_df = df[df['Sex'] == 'F']
disciplines = df['Sport'].unique()
man_players_by_discipline = {}
woman_players_by_discipline = {}
for d in disciplines:
    man_players_by_discipline[d] = man_df[man_df['Sport'] == d]
    woman_players_by_discipline[d] = woman_df[woman_df['Sport'] == d]

model = LinearRegression()

# %% [markdown]
# ## Choose sport disciplines with given lenght

# %%
d_list = disciplines.tolist()
to_delete = []
for d in d_list:
    if len(man_players_by_discipline[d]) < 300:
        to_delete.append(d)
for d in to_delete:
    d_list.remove(d)

disciplines = np.array(d_list)
print(disciplines)
# Out:
# ['Athletics' 'Rowing' 'Cycling' 'Swimming']

# %% [markdown]
# ### Print NaN percentage

# %%
d_list = disciplines.tolist()
for d in d_list:
    show_nan_percentage(man_players_by_discipline[d])
# Out:
# Name      0.000000
# Sex       0.000000
# Age       0.000000
# Height    9.290541
# Weight    9.037162
# Team      0.000000
# NOC       0.000000
# Sport     0.000000
# dtype: float64
# Name      0.000000
# Sex       0.000000
# Age       0.000000
# Height    6.344411
# Weight    5.740181
# Team      0.000000
# NOC       0.000000
# Sport     0.000000
# dtype: float64
# Name      0.000000
# Sex       0.000000
# Age       0.000000
# Height    6.853583
# Weight    6.853583
# Team      0.000000
# NOC       0.000000
# Sport     0.000000
# dtype: float64
# Name      0.000000
# Sex       0.000000
# Age       0.000000
# Height    7.142857
# Weight    9.325397
# Team      0.000000
# NOC       0.000000
# Sport     0.000000
# dtype: float64

# %% [markdown]
# ## Regression for different sports

# %%
imputators = [
    (None, "Drop NaN"),
    (lambda dataset: SimpleImputer(missing_values=np.nan, strategy='mean').fit_transform(dataset), "Mean Imputation"),
    (lambda dataset: pd.DataFrame(data=dataset).interpolate(limit_direction='both').to_numpy(), "Interpolation imputation"),
    (lambda dataset: pd.DataFrame(data=dataset).fillna(method='ffill').to_numpy(), "Hot-dect imputation"),
    (lambda dataset: IterativeImputer(max_iter=20, random_state=0).fit_transform(dataset), "Regression imputation")
]
f, axarr = plt.subplots(len(disciplines),len(imputators), sharex=True, sharey=True,figsize=(20,15))
f.suptitle('Zależność wzrostu i wagi męskich zawodników według dyscypliny')
for i in range(0,len(disciplines)):
    print("------ ",disciplines[i], " ------")
    output_array = []
    for j, (imputer, title) in enumerate(imputators):
        regression_set = man_players_by_discipline[disciplines[i]][['Height', 'Weight']]
        if imputer == None:
            regression_set = regression_set.dropna()
            xs = regression_set['Height'].to_numpy().reshape((-1,1))
            ys = regression_set['Weight'].to_numpy().reshape((-1,1))
        if imputer != None:
            print(title)
            xs = regression_set['Height'].to_numpy().reshape((-1,1))
            ys = regression_set['Weight'].to_numpy().reshape((-1,1))
            xs = imputer(xs)
            ys = imputer(ys)
        
        x_train,x_test,y_train,y_test=train_test_split(xs,ys,test_size=0.4)
        model.fit(x_train,y_train)
        y_test = model.predict(x_test)
        result_df = pd.DataFrame({
            'Height': xs[:,0],
            'Weight' : ys[:,0]
        })
        print(result_df.describe())
        print(title, ': coefficients:', model.coef_)
        t_title = title + "->" + disciplines[i] 
        output_array.append([title, model.coef_])
        axarr[i,j].set_title(t_title)
        axarr[i,j].scatter(x_train, y_train, color="red")
        axarr[i,j].plot(x_test, y_test, color="blue", linewidth=1)
    display(tabulate(output_array, headers=['Imputation:', 'model coefficient'], tablefmt="html"))
    print("\n\n")
# Out:
# ------  Athletics  ------
#             Height       Weight
# count  1017.000000  1017.000000
# mean    180.967552    74.723697
# std       9.039934    17.777368
# min     151.000000    47.000000
# 25%     175.000000    63.000000
# 50%     181.000000    71.000000
# 75%     187.000000    80.000000
# max     208.000000   165.000000
# Drop NaN : coefficients: [[1.32682442]]
# Mean Imputation
#             Height       Weight
# count  1184.000000  1184.000000
# mean    180.934823    74.736305
# std       8.581539    17.117591
# min     151.000000    47.000000
# 25%     175.000000    64.000000
# 50%     180.934823    73.000000
# 75%     187.000000    80.000000
# max     208.000000   165.000000
# Mean Imputation : coefficients: [[1.30453323]]
# Interpolation imputation
#             Height       Weight
# count  1184.000000  1184.000000
# mean    180.936655    74.788851
# std       8.807741    17.589350
# min     151.000000    47.000000
# 25%     175.000000    63.000000
# 50%     181.000000    71.750000
# 75%     187.000000    80.000000
# max     208.000000   165.000000
# Interpolation imputation : coefficients: [[1.32648534]]
# Hot-dect imputation
#             Height       Weight
# count  1184.000000  1184.000000
# mean    180.862331    74.732264
# std       8.925756    17.937247
# min     151.000000    47.000000
# 25%     175.000000    63.000000
# 50%     181.000000    71.000000
# 75%     187.000000    80.000000
# max     208.000000   165.000000
# Hot-dect imputation : coefficients: [[1.26503183]]
# Regression imputation
#             Height       Weight
# count  1184.000000  1184.000000
# mean    180.934823    74.736305
# std       8.581539    17.117591
# min     151.000000    47.000000
# 25%     175.000000    64.000000
# 50%     180.934823    73.000000
# 75%     187.000000    80.000000
# max     208.000000   165.000000
# Regression imputation : coefficients: [[1.19155276]]
# '<table>\n<thead>\n<tr><th>Imputation:             </th><th style="text-align: right;">  model coefficient</th></tr>\n</thead>\n<tbody>\n<tr><td>Drop NaN                </td><td style="text-align: right;">            1.32682</td></tr>\n<tr><td>Mean Imputation         </td><td style="text-align: right;">            1.30453</td></tr>\n<tr><td>Interpolation imputation</td><td style="text-align: right;">            1.32649</td></tr>\n<tr><td>Hot-dect imputation     </td><td style="text-align: right;">            1.26503</td></tr>\n<tr><td>Regression imputation   </td><td style="text-align: right;">            1.19155</td></tr>\n</tbody>\n</table>'
# ------  Rowing  ------
#            Height      Weight
# count  293.000000  293.000000
# mean   189.696246   86.143345
# std      7.579706   12.117854
# min    152.000000   53.000000
# 25%    185.000000   73.000000
# 50%    190.000000   90.000000
# 75%    195.000000   95.000000
# max    209.000000  110.000000
# Drop NaN : coefficients: [[1.3464668]]
# Mean Imputation
#            Height      Weight
# count  331.000000  331.000000
# mean   189.922581   86.224359
# std      7.312120   11.846275
# min    152.000000   53.000000
# 25%    186.000000   73.000000
# 50%    190.000000   90.000000
# 75%    195.000000   95.000000
# max    209.000000  110.000000
# Mean Imputation : coefficients: [[1.29902188]]
# Interpolation imputation
#            Height      Weight
# count  331.000000  331.000000
# mean   190.013595   86.095166
# std      7.465560   11.999022
# min    152.000000   53.000000
# 25%    186.000000   73.000000
# 50%    190.000000   90.000000
# 75%    195.000000   95.000000
# max    209.000000  110.000000
# Interpolation imputation : coefficients: [[1.26280239]]
# Hot-dect imputation
#            Height      Weight
# count  331.000000  331.000000
# mean   190.184290   85.930514
# std      7.569828   12.224095
# min    152.000000   53.000000
# 25%    186.000000   73.000000
# 50%    191.000000   90.000000
# 75%    196.000000   95.000000
# max    209.000000  110.000000
# Hot-dect imputation : coefficients: [[1.25362987]]
# Regression imputation
#            Height      Weight
# count  331.000000  331.000000
# mean   189.922581   86.224359
# std      7.312120   11.846275
# min    152.000000   53.000000
# 25%    186.000000   73.000000
# 50%    190.000000   90.000000
# 75%    195.000000   95.000000
# max    209.000000  110.000000
# Regression imputation : coefficients: [[1.29607766]]
# '<table>\n<thead>\n<tr><th>Imputation:             </th><th style="text-align: right;">  model coefficient</th></tr>\n</thead>\n<tbody>\n<tr><td>Drop NaN                </td><td style="text-align: right;">            1.34647</td></tr>\n<tr><td>Mean Imputation         </td><td style="text-align: right;">            1.29902</td></tr>\n<tr><td>Interpolation imputation</td><td style="text-align: right;">            1.2628 </td></tr>\n<tr><td>Hot-dect imputation     </td><td style="text-align: right;">            1.25363</td></tr>\n<tr><td>Regression imputation   </td><td style="text-align: right;">            1.29608</td></tr>\n</tbody>\n</table>'
# ------  Cycling  ------
#            Height      Weight
# count  282.000000  282.000000
# mean   179.230496   72.592199
# std      6.609068    9.649019
# min    164.000000   52.000000
# 25%    175.000000   65.000000
# 50%    180.000000   70.000000
# 75%    184.000000   79.000000
# max    196.000000  100.000000
# Drop NaN : coefficients: [[0.86037448]]
# Mean Imputation
#            Height      Weight
# count  321.000000  321.000000
# mean   179.260870   72.561873
# std      6.317053    9.160992
# min    164.000000   52.000000
# 25%    175.000000   66.000000
# 50%    179.260870   72.000000
# 75%    183.000000   78.000000
# max    196.000000  100.000000
# Mean Imputation : coefficients: [[0.7949816]]
# Interpolation imputation
#            Height      Weight
# count  321.000000  321.000000
# mean   179.166667   72.532710
# std      6.412350    9.335113
# min    164.000000   52.000000
# 25%    175.000000   65.000000
# 50%    179.000000   70.000000
# 75%    184.000000   78.000000
# max    196.000000  100.000000
# Interpolation imputation : coefficients: [[0.87690758]]
# Hot-dect imputation
#            Height      Weight
# count  321.000000  321.000000
# mean   179.242991   72.595016
# std      6.452482    9.399360
# min    164.000000   52.000000
# 25%    175.000000   65.000000
# 50%    180.000000   70.000000
# 75%    184.000000   79.000000
# max    196.000000  100.000000
# Hot-dect imputation : coefficients: [[0.75503531]]
# Regression imputation
#            Height      Weight
# count  321.000000  321.000000
# mean   179.260870   72.561873
# std      6.317053    9.160992
# min    164.000000   52.000000
# 25%    175.000000   66.000000
# 50%    179.260870   72.000000
# 75%    183.000000   78.000000
# max    196.000000  100.000000
# Regression imputation : coefficients: [[0.80191753]]
# '<table>\n<thead>\n<tr><th>Imputation:             </th><th style="text-align: right;">  model coefficient</th></tr>\n</thead>\n<tbody>\n<tr><td>Drop NaN                </td><td style="text-align: right;">           0.860374</td></tr>\n<tr><td>Mean Imputation         </td><td style="text-align: right;">           0.794982</td></tr>\n<tr><td>Interpolation imputation</td><td style="text-align: right;">           0.876908</td></tr>\n<tr><td>Hot-dect imputation     </td><td style="text-align: right;">           0.755035</td></tr>\n<tr><td>Regression imputation   </td><td style="text-align: right;">           0.801918</td></tr>\n</tbody>\n</table>'
# ------  Swimming  ------
#            Height      Weight
# count  439.000000  439.000000
# mean   186.318907   79.883827
# std      7.559407    8.610161
# min    153.000000   50.000000
# 25%    182.000000   74.000000
# 50%    187.000000   80.000000
# 75%    192.000000   85.000000
# max    208.000000  110.000000
# Drop NaN : coefficients: [[0.84120958]]
# Mean Imputation
#            Height      Weight
# count  504.000000  504.000000
# mean   186.232906   79.954048
# std      7.247350    8.298367
# min    153.000000   50.000000
# 25%    183.000000   75.000000
# 50%    186.232906   79.954048
# 75%    191.000000   85.000000
# max    208.000000  110.000000
# Mean Imputation : coefficients: [[0.8127651]]
# Interpolation imputation
#            Height      Weight
# count  504.000000  504.000000
# mean   186.226190   80.010913
# std      7.395557    8.551908
# min    153.000000   50.000000
# 25%    182.000000   74.000000
# 50%    186.000000   80.000000
# 75%    191.000000   85.000000
# max    208.000000  110.000000
# Interpolation imputation : coefficients: [[0.74482742]]
# Hot-dect imputation
#            Height      Weight
# count  504.000000  504.000000
# mean   186.188492   80.017857
# std      7.458712    8.809993
# min    153.000000   50.000000
# 25%    182.000000   74.000000
# 50%    186.000000   80.000000
# 75%    191.000000   85.000000
# max    208.000000  110.000000
# Hot-dect imputation : coefficients: [[0.78878861]]
# Regression imputation
#            Height      Weight
# count  504.000000  504.000000
# mean   186.232906   79.954048
# std      7.247350    8.298367
# min    153.000000   50.000000
# 25%    183.000000   75.000000
# 50%    186.232906   79.954048
# 75%    191.000000   85.000000
# max    208.000000  110.000000
# Regression imputation : coefficients: [[0.77819243]]
# '<table>\n<thead>\n<tr><th>Imputation:             </th><th style="text-align: right;">  model coefficient</th></tr>\n</thead>\n<tbody>\n<tr><td>Drop NaN                </td><td style="text-align: right;">           0.84121 </td></tr>\n<tr><td>Mean Imputation         </td><td style="text-align: right;">           0.812765</td></tr>\n<tr><td>Interpolation imputation</td><td style="text-align: right;">           0.744827</td></tr>\n<tr><td>Hot-dect imputation     </td><td style="text-align: right;">           0.788789</td></tr>\n<tr><td>Regression imputation   </td><td style="text-align: right;">           0.778192</td></tr>\n</tbody>\n</table>'
